# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 5.94MB/s]

# %%
model.info()
# Out:
# YOLOv8n summary: 225 layers, 3157200 parameters, 0 gradients
# (225, 3157200, 0, 0.0)

# %%
results = model.train(data='config.yaml', epochs=100)
# Out:
# Ultralytics YOLOv8.0.184  Python-3.8.16 torch-2.0.1+cpu CPU (13th Gen Intel Core(TM) i9-13900K)
# ...
